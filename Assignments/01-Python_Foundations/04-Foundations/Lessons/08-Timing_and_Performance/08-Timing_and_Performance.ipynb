# %% [markdown]
# # ⏱️ 08 - Timing and Performance
#
# In data science, performance matters. Some code runs fast, some slow.
# Jupyter/IPython gives us tools to measure runtime easily.
#
# In this notebook you will learn:
# - `%time` and `%timeit` for single expressions
# - `%%time` and `%%timeit` for entire cells
# - Comparing loops, list comprehensions, and NumPy
# - Why performance awareness is important

# %% [markdown]
# ## 1. `%time`

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 20.1 ms, sys: 87 μs, total: 20.1 ms
# Wall time: 35.4 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Use `%time` to measure how long it takes to sort a list of 1 million random numbers.

# %%
mlist = list(range(1000000))

# %time mlist.sort()
# Out:
# CPU times: user 6.4 ms, sys: 787 μs, total: 7.18 ms
# Wall time: 6.87 ms

# %% [markdown]
# ## 2. `%timeit`

# %%
numbers = list(range(1_000))
# %timeit [x**2 for x in numbers]
# Out:
# 48 μs ± 9.75 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Compare `%timeit` results for a list comprehension vs. a `for` loop that builds the same list.

# %%
listm = list(range(1000))
# %timeit [x**2 for x in numbers]
# Out:
# 45.8 μs ± 3.81 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
listn = [1000]

# %timeit for x in listn: x = x**2
# Out:
# 86.4 ns ± 8.28 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ## 3. `%%time` for a Whole Cell

# %%
# %%time
total = 0
for i in range(1_000_000):
    total += i
total
# Out:
# CPU times: user 124 ms, sys: 2.76 ms, total: 127 ms
# Wall time: 141 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Wrap a longer multi-line operation with `%%time` to measure its runtime.

# %%
# %%time
mylist = list(ran(1000000))

for x in mylist:
    if x == 500000:
        print(x)
# Out:
# CPU times: user 9 μs, sys: 1 μs, total: 10 μs
# Wall time: 13.4 μs
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'mylist = list(ran(1000000))\n\nfor x in mylist:\n    if x == 500000:\n        print(x)\n')
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/magics/execution.py:1452, in ExecutionMagics.time(self, line, cell, local_ns)
#    1450 if interrupt_occured:
#    1451     if exit_on_interrupt and captured_exception:
# -> 1452         raise captured_exception
#    1453     return
#    1454 return out
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/magics/execution.py:1416, in ExecutionMagics.time(self, line, cell, local_ns)
#    1414 st = clock2()
#    1415 try:
# -> 1416     exec(code, glob, local_ns)
#    1417     out = None
#    1418     # multi-line %%time case
#
# File <timed exec>:1
#
# NameError: name 'ran' is not defined

# %% [markdown]
# ## 4. Comparing Loops vs. NumPy

# %%
import numpy as np

numbers = np.arange(1_000_000)

# Python loop
# %timeit [x**2 for x in numbers]

# NumPy vectorized
# %timeit numbers**2

# %% [markdown]
# ✅ **Your Turn**: Try squaring numbers with a Python loop, list comprehension, and NumPy array. Compare times.

# %%
import numpy as np
listmine = [100]
# %timeit for x in listmine: x = x**2

# %timeit listmine2 = [x**2 for x in range(100)]

listmine3 = np.arange(100)
# %timeit listmine3**2
# Out:
# 83.1 ns ± 12.1 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)
# 4.92 μs ± 766 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 512 ns ± 60.5 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %% [markdown]
# ## 5. Why This Matters
# - Performance differences become huge with large datasets.
# - Vectorized operations (like NumPy, Pandas) are usually faster.
# - `%timeit` is your friend when deciding how to implement something.

# %% [markdown]
# ---
# ### Summary
# - `%time` and `%timeit` measure execution speed.
# - `%%time` and `%%timeit` work on whole cells.
# - Loops are slower than list comprehensions, which are slower than NumPy.
# - Always measure performance before optimizing.
