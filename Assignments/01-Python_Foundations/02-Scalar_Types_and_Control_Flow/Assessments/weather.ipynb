# %% [markdown]
# This is Jose Espino program for weather

# %%
weather = input("Whats the weather like")
print(weather)
if weather == "sunny":
    print ("bring sunscreen")
elif weather == "raining":
   print ("take an umbrella") 
else: 
    print ("check the weather")
# Out:
# sunny
# bring sunscreen
