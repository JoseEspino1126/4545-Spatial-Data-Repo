# %% [markdown]
# # 01 — Click Interactions
#
# The last lesson introduced the event system and showed how to extract coordinates from a click. This lesson uses those coordinates to **build things** — markers with labels, growing lists of points, a live path that draws itself as you click, and finally a GeoJSON export of everything you collected.
#
# ```
# click  →  lat/lon  →  create feature  →  add to map
# ```

# %% [markdown]
# ## Setup

# %%
from ipyleaflet import Map, Marker, Polyline, GeoJSON
from ipywidgets import HTML

WICHITA_FALLS = (33.9137, -98.4934)

# %% [markdown]
# ## Capturing Click Coordinates
#
# Quick recap of the pattern from the last lesson — filter to `"click"` events, unpack `coordinates`.
#
# ```
# click  →  kwargs["coordinates"]  →  (lat, lon)
# ```
#
# Everything in this lesson starts from this two-line extract:

# %%
def on_click(**kwargs):
    if kwargs.get("type") != "click":
        return
    lat, lon = kwargs["coordinates"]   # always this line
    print(f"lat={lat:.5f}  lon={lon:.5f}")

m = Map(center=WICHITA_FALLS, zoom=12)
m.on_interaction(on_click)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Numbered Markers with Popups
#
# A bare marker is hard to tell apart once you have placed several. Add a sequential number and a popup that shows the exact coordinates.

# %%
m = Map(center=WICHITA_FALLS, zoom=12)
count = [0]  # list so the closure can mutate it

def place_numbered_marker(**kwargs):
    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]
    count[0] += 1

    marker = Marker(location=(lat, lon), title=f"Point {count[0]}")
    marker.popup = HTML(value=f"""
        <b>Point {count[0]}</b><br>
        lat: {lat:.5f}<br>
        lon: {lon:.5f}
    """)
    m.add(marker)

m.on_interaction(place_numbered_marker)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Click several locations, then click each marker to see its popup.

# %% [markdown]
# ## Storing Clicked Points
#
# A marker is a visual object on the map — but it lives in ipyleaflet, not in Python. To use your clicked coordinates later (for computation, export, or building geometry), collect them into a plain Python list.
#
# ```python
# clicked_points = []   # grows with every click
# ```
#
# Each click appends one `(lat, lon)` tuple.

# %%
m = Map(center=WICHITA_FALLS, zoom=12)
clicked_points = []

def collect_point(**kwargs):
    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]
    clicked_points.append((lat, lon))

    # Visual confirmation on the map
    m.add(Marker(location=(lat, lon), title=f"Point {len(clicked_points)}"))

    # Text feedback below the cell
    print(f"[{len(clicked_points)}]  ({lat:.5f}, {lon:.5f})")

m.on_interaction(collect_point)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
# Inspect the list after clicking
print(f"{len(clicked_points)} points collected:")
for i, (lat, lon) in enumerate(clicked_points):
    print(f"  {i+1}.  ({lat:.5f}, {lon:.5f})")
# Out:
# 4 points collected:
#   1.  (33.92826, -98.61191)
#   2.  (33.92940, -98.52024)
#   3.  (33.90889, -98.51475)
#   4.  (33.93026, -98.56796)

# %% [markdown]
# ## Building a Live Path
#
# Once coordinates are stored in a list, you can connect them into a line. A `Polyline` takes a list of `(lat, lon)` tuples and draws them as a connected path.
#
# The trick: update the `Polyline`'s `locations` property each time a new point arrives. Because the polyline is a widget, the map redraws instantly — no cell re-run.

# %%
m = Map(center=WICHITA_FALLS, zoom=12)

path_points = []
path_line = Polyline(locations=[], color="#e74c3c", weight=3)
m.add(path_line)

def build_path(**kwargs):
    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]
    path_points.append((lat, lon))

    # Drop a marker at the new point
    m.add(Marker(location=(lat, lon), title=f"Point {len(path_points)}"))

    # Update the line — widget redraws automatically
    path_line.locations = path_points.copy()

    print(f"Path has {len(path_points)} point(s)")

m.on_interaction(build_path)
m
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# Click several locations in sequence. Each click extends the red line to the new point.
#
# The list of points in `path_points` is the data behind what you see — the map is just visualizing it.

# %% [markdown]
# ## Exporting Clicked Points as GeoJSON
#
# Collected coordinates are only useful if you can use them elsewhere. Convert `path_points` to a GeoJSON FeatureCollection and save it to a file.
#
# Remember: GeoJSON coordinates are `[lon, lat]` — the reverse of ipyleaflet's `(lat, lon)`.

# %%
import json

def points_to_geojson(points):
    """Convert a list of (lat, lon) tuples to a GeoJSON FeatureCollection."""
    features = [
        {
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [lon, lat]   # GeoJSON order: [lon, lat]
            },
            "properties": {"index": i + 1}
        }
        for i, (lat, lon) in enumerate(points)
    ]
    return {"type": "FeatureCollection", "features": features}

# Convert and inspect
fc = points_to_geojson(path_points)
print(json.dumps(fc, indent=2))
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.56760485282456,
#           33.91626630326347
#         ]
#       },
#       "properties": {
#         "index": 1
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.5164597528671,
#           33.91911533292223
#         ]
#       },
#       "properties": {
#         "index": 2
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.51405696293624,
#           33.89774528872983
#         ]
#       },
#       "properties": {
#         "index": 3
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.5624560172584,
#           33.88691575491083
#         ]
#       },
#       "properties": {
#         "index": 4
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.59334903065547,
#           33.904584285777304
#         ]
#       },
#       "properties": {
#         "index": 5
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.58682717227167,
#           33.93079535851445
#         ]
#       },
#       "properties": {
#         "index": 6
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.54563648774217,
#           33.936777190403404
#         ]
#       },
#       "properties": {
#         "index": 7
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.48213418242588,
#           33.92908618651223
#         ]
#       },
#       "properties": {
#         "index": 8
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.47938813679056,
#           33.891475726221095
#         ]
#       },
#       "properties": {
#         "index": 9
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.5078783602568,
#           33.869528628217815
#         ]
#       },
#       "properties": {
#         "index": 10
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.58167833670548,
#           33.86667794161407
#         ]
#       },
#       "properties": {
#         "index": 11
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.61943646419085,
#           33.89546550114607
#         ]
#       },
#       "properties": {
#         "index": 12
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.61428762862467,
#           33.949878782322
#         ]
#       },
#       "properties": {
#         "index": 13
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.5459797434466,
#           33.96297835761027
#         ]
#       },
#       "properties": {
#         "index": 14
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.4684039542494,
#           33.95158753694968
#         ]
#       },
#       "properties": {
#         "index": 15
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.44025698648755,
#           33.88891077235388
#         ]
#       },
#       "properties": {
#         "index": 16
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.47767185826851,
#           33.860976282837136
#         ]
#       },
#       "properties": {
#         "index": 17
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.58991630781715,
#           33.84634009704382
#         ]
#       },
#       "properties": {
#         "index": 18
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.66955163124085,
#           33.886250553176076
#         ]
#       },
#       "properties": {
#         "index": 19
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.6654325627879,
#           33.966015466838044
#         ]
#       },
#       "properties": {
#         "index": 20
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.54323353201706,
#           34.01725345182776
#         ]
#       },
#       "properties": {
#         "index": 21
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.40043915898147,
#           34.00131605644328
#         ]
#       },
#       "properties": {
#         "index": 22
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.36336754290491,
#           33.86686780475492
#         ]
#       },
#       "properties": {
#         "index": 23
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.43064566096977,
#           33.81896214636997
#         ]
#       },
#       "properties": {
#         "index": 24
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.60776560444661,
#           33.80526988326154
#         ]
#       },
#       "properties": {
#         "index": 25
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.71211533858799,
#           33.87941008583186
#         ]
#       },
#       "properties": {
#         "index": 26
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.72035347549388,
#           33.97968195034303
#         ]
#       },
#       "properties": {
#         "index": 27
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.56520189709946,
#           34.06504768584395
#         ]
#       },
#       "properties": {
#         "index": 28
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.3729787026285,
#           34.05708385067742
#         ]
#       },
#       "properties": {
#         "index": 29
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.30295453892836,
#           33.85546413182517
#         ]
#       },
#       "properties": {
#         "index": 30
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.39906613616384,
#           33.768746469922185
#         ]
#       },
#       "properties": {
#         "index": 31
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.63385303798194,
#           33.74476951550546
#         ]
#       },
#       "properties": {
#         "index": 32
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.76429020565864,
#           33.86230651833654
#         ]
#       },
#       "properties": {
#         "index": 33
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.79037763919402,
#           34.00245454102401
#         ]
#       },
#       "properties": {
#         "index": 34
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.58991630781715,
#           34.11736283767759
#         ]
#       },
#       "properties": {
#         "index": 35
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.32217685837544,
#           34.10712980863202
#         ]
#       },
#       "properties": {
#         "index": 36
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.21233503296345,
#           33.836074393121116
#         ]
#       },
#       "properties": {
#         "index": 37
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.33316104091664,
#           33.720785856169
#         ]
#       },
#       "properties": {
#         "index": 38
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.63659908361721,
#           33.713932150882734
#         ]
#       },
#       "properties": {
#         "index": 39
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.81371902709405,
#           33.837215087789225
#         ]
#       },
#       "properties": {
#         "index": 40
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.85079064317061,
#           34.04229188582648
#         ]
#       },
#       "properties": {
#         "index": 41
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.98671990211794,
#           34.02066821879432
#         ]
#       },
#       "properties": {
#         "index": 42
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.89472737333541,
#           33.91246726337754
#         ]
#       },
#       "properties": {
#         "index": 43
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.89472737333541,
#           33.91246726337754
#         ]
#       },
#       "properties": {
#         "index": 44
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -97.69337214833115,
#           33.94538479413648
#         ]
#       },
#       "properties": {
#         "index": 45
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.53915420400344,
#           34.28646995244734
#         ]
#       },
#       "properties": {
#         "index": 46
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.78080621990978,
#           33.58233642831138
#         ]
#       },
#       "properties": {
#         "index": 47
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -97.81694420191964,
#           33.495342752732064
#         ]
#       },
#       "properties": {
#         "index": 48
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -97.63570518998985,
#           33.936270375516216
#         ]
#       },
#       "properties": {
#         "index": 49
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.0338818071083,
#           34.275122625646226
#         ]
#       },
#       "properties": {
#         "index": 50
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -99.3657139402286,
#           34.059232648893904
#         ]
#       },
#       "properties": {
#         "index": 51
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.60780534488592,
#           33.495342752732064
#         ]
#       },
#       "properties": {
#         "index": 52
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -97.22929043596552,
#           33.6715283116136
#         ]
#       },
#       "properties": {
#         "index": 53
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -98.89064804532178,
#           34.31596583162717
#         ]
#       },
#       "properties": {
#         "index": 54
#       }
#     }
#   ]
# }

# %%
# Save to file
output_path = "clicked_points.geojson"

with open(output_path, "w") as f:
    json.dump(fc, f, indent=2)

print(f"Saved {len(path_points)} points to {output_path}")
# Out:
# Saved 54 points to clicked_points.geojson

# %%
# Reload the saved file and display it — closes the loop
with open(output_path) as f:
    saved = json.load(f)

m2 = Map(center=WICHITA_FALLS, zoom=12)
m2.add(GeoJSON(data=saved))
m2
# Out:
# Map(center=[33.9137, -98.4934], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ## Exercise A
#
# Click the `build_path` map above to collect at least 3 points. Then, in the cell below, convert `path_points` into a single **`LineString`** GeoJSON feature (not a FeatureCollection of Points). Print the result.
#
# Remember: GeoJSON coordinate order is `[lon, lat]`.

# %%
import json

# After clicking the map above to collect path_points, run this cell.
# Convert path_points into a single LineString GeoJSON feature (not a collection of Points).
# Print the result.
# Your code here

coords = []

for lat, lon in path_points:
    coords.append([lon, lat])

linestring = {
    "type": "Feature",
    "geometry": {
        "type": "LineString",
        "coordinates": coords
    },
    "properties": {}
}

print(linestring)
# Out:
# {'type': 'Feature', 'geometry': {'type': 'LineString', 'coordinates': [[-98.56760485282456, 33.91626630326347], [-98.5164597528671, 33.91911533292223], [-98.51405696293624, 33.89774528872983], [-98.5624560172584, 33.88691575491083], [-98.59334903065547, 33.904584285777304], [-98.58682717227167, 33.93079535851445], [-98.54563648774217, 33.936777190403404], [-98.48213418242588, 33.92908618651223], [-98.47938813679056, 33.891475726221095], [-98.5078783602568, 33.869528628217815], [-98.58167833670548, 33.86667794161407], [-98.61943646419085, 33.89546550114607], [-98.61428762862467, 33.949878782322], [-98.5459797434466, 33.96297835761027], [-98.4684039542494, 33.95158753694968], [-98.44025698648755, 33.88891077235388], [-98.47767185826851, 33.860976282837136], [-98.58991630781715, 33.84634009704382], [-98.66955163124085, 33.886250553176076], [-98.6654325627879, 33.966015466838044], [-98.54323353201706, 34.01725345182776], [-98.40043915898147, 34.00131605644328], [-98.36336754290491, 33.86686780475492], [-98.43064566096977, 33.81896214636997], [-98.60776560444661, 33.80526988326154], [-98.71211533858799, 33.87941008583186], [-98.72035347549388, 33.97968195034303], [-98.56520189709946, 34.06504768584395], [-98.3729787026285, 34.05708385067742], [-98.30295453892836, 33.85546413182517], [-98.39906613616384, 33.768746469922185], [-98.63385303798194, 33.74476951550546], [-98.76429020565864, 33.86230651833654], [-98.79037763919402, 34.00245454102401], [-98.58991630781715, 34.11736283767759], [-98.32217685837544, 34.10712980863202], [-98.21233503296345, 33.836074393121116], [-98.33316104091664, 33.720785856169], [-98.63659908361721, 33.713932150882734], [-98.81371902709405, 33.837215087789225], [-98.85079064317061, 34.04229188582648], [-98.98671990211794, 34.02066821879432], [-98.89472737333541, 33.91246726337754], [-98.89472737333541, 33.91246726337754], [-97.69337214833115, 33.94538479413648], [-98.53915420400344, 34.28646995244734], [-98.78080621990978, 33.58233642831138], [-97.81694420191964, 33.495342752732064], [-97.63570518998985, 33.936270375516216], [-98.0338818071083, 34.275122625646226], [-99.3657139402286, 34.059232648893904], [-98.60780534488592, 33.495342752732064], [-97.22929043596552, 33.6715283116136], [-98.89064804532178, 34.31596583162717]]}, 'properties': {}}

# %% [markdown]
# ## Exercise B
#
# Add an **Undo** button to the live path builder. Each click of the button should:
#
# 1. Remove the last marker from the map
# 2. Pop the last entry from the points list
# 3. Update the `Polyline` to reflect the shorter path

# %%
from ipyleaflet import Map, Marker, Polyline
from ipywidgets import Button, HBox, VBox

m = Map(center=WICHITA_FALLS, zoom=12)

undo_points = []
undo_markers = []
undo_line = Polyline(locations=[], color="#e74c3c", weight=3)
m.add(undo_line)

# Add an "Undo" button that removes the last marker and pops the last point
# Update the polyline after each undo
# Your code here
undo_button = Button(description="Undo")

def handle_click(**kwargs):

    if kwargs.get("type") != "click":
        return

    lat, lon = kwargs["coordinates"]

    marker = Marker(location=(lat, lon))
    m.add_layer(marker)

    undo_markers.append(marker)
    undo_points.append((lat, lon))

    undo_line.locations = undo_points


def undo_action(b):

    if not undo_points:
        return

    # remove last marker
    last_marker = undo_markers.pop()
    m.remove_layer(last_marker)

    # remove last point
    undo_points.pop()

    # update line
    undo_line.locations = undo_points


m.on_interaction(handle_click)
undo_button.on_click(undo_action)

VBox([undo_button, m])
# Out:
# VBox(children=(Button(description='Undo', style=ButtonStyle()), Map(center=[33.9137, -98.4934], controls=(Zoom…

# %% [markdown]
# ---
#
# ## Check Your Understanding
#
# Build a map where:
#
# 1. Each click drops a numbered marker and appends `(lat, lon)` to a list
# 2. After collecting at least three points, run a second cell that prints each coordinate and exports them to `my_points.geojson`
#
# ```python
# # your answer here
# m = Map(center=WICHITA_FALLS, zoom=12)
#
# points = []
# markers = []
# counter = 0
#
# def handle_click(**kwargs):
#
#     global counter
#
#     if kwargs.get("type") != "click":
#         return
#
#     counter += 1
#     lat, lon = kwargs["coordinates"]
#
#     # store point
#     points.append((lat, lon))
#
#     # numbered marker (simple label via title)
#     marker = Marker(
#         location=(lat, lon),
#         title=f"{counter}"
#     )
#
#     m.add_layer(marker)
#     markers.append(marker)
#
# m.on_interaction(handle_click)
# m
# ```

# %% [markdown]
# ## Next
#
# In [02 — Dynamic Layers](./02-Dynamic_Layers.ipynb), we add and remove entire GeoJSON layers at runtime — toggling, swapping, and clearing them while the map is live.
