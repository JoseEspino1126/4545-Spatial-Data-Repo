# %%
import sys
print("Python executable:\n", sys.executable)

assert ".venv" in sys.executable, """
WRONG KERNEL.
Pick the kernel that ends with '(.venv)' (e.g., 4543 02 Missile Geo (.venv)).
"""
print("✅ Using .venv kernel")
# Out:
# Python executable:
#  /workspaces/4545-Spatial-Data-Repo/.venv/bin/python
# ✅ Using .venv kernel

# %%
import folium
import shapefile
import shapely
import geojson
import numpy
import rich

print("✅ Imports OK")
print("pyshp (shapefile) from:", shapefile.__file__)
# Out:
# ✅ Imports OK
# pyshp (shapefile) from: /workspaces/4545-Spatial-Data-Repo/.venv/lib/python3.12/site-packages/shapefile.py

# %%
m = folium.Map(location=[0, 0], zoom_start=2, tiles="OpenStreetMap")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 m = folium.Map(location=[0, 0], zoom_start=2, tiles="OpenStreetMap")
#
# NameError: name 'folium' is not defined
