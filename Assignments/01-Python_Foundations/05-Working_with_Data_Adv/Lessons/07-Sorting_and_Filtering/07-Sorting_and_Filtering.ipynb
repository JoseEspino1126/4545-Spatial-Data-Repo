# %% [markdown]
# # 🧮 Sorting & Filtering in Pandas
#
# ## 🔹 LEARNING GOALS:
# - Sort rows using `.sort_values()`
# - Filter data using conditional logic
# - Chain multiple filters together
# - Use `.query()` for readable filtering

# %% [markdown]
# ### 📥 1. Load the Dataset

# %%
import pandas as pd

df = pd.read_csv("../../data/ufo.csv")
df.head()
# Out:
#           date_time             city_area state country ufo_shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#    encounter_length described_encounter_length  \
# 0            2700.0                 45 minutes
# 1            7200.0                    1-2 hrs
# 2              20.0                 20 seconds
# 3              20.0                   1/2 hour
# 4             900.0                 15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#     latitude   longitude
# 0  29.883056  -97.941111
# 1  29.384210  -98.581082
# 2  53.200000   -2.916667
# 3  28.978333  -96.645833
# 4  21.418056 -157.803611

# %% [markdown]
# ### 🔢 2. Sorting Data

# %%
# Sort by math_score
df.sort_values(by="math_score")
# Out:
#      first_name  last_name  math_score  science_score
# 28      Melanie      Baker          60             94
# 2        Joshua      Adams          61            100
# 13        James      Cohen          61             66
# 19         Adam      Adams          61             70
# 44  Christopher      Brown          62             64
# 12      Anthony    Hawkins          62             74
# 49      Michael   Valencia          65             91
# 14        Debra    Cameron          65             84
# 37    Christine      Hicks          65             80
# 9       Anthony       Gray          65             74
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 7   Christopher     Daniel          66             64
# 47       Joshua       Rice          67             80
# 1         Angel      Clark          67             78
# 6      Patricia    Jackson          68             72
# 33       Teresa      Hurst          69             77
# 29    Cassandra     Wright          70             75
# 21        Helen       Hahn          72             82
# 34     Nicholas       Ross          73            100
# 15          Amy    Parsons          73             77
# 24        Susan       Rios          74             64
# 5         Erica      Lynch          74             96
# 16      Jeffrey      Perez          74             89
# 4          Jill       Wong          75             83
# 43        Keith  Henderson          76             77
# 3       Jeffrey     Zuniga          77             99
# 27        Colin      Ellis          77             70
# 32       Amanda   Richards          77             84
# 35       Andrea   Robinson          81             95
# 31      Jessica      Baker          81             89
# 40        Janet  Rodriguez          82             62
# 41      Brandon     Burton          82             80
# 48      Cynthia     Maddox          84             73
# 38     Michelle      Davis          84             63
# 23         Eric    Edwards          86             77
# 11      William     Bowman          87             65
# 30      Lindsay    Hoffman          87             70
# 25      Matthew     Foster          88             98
# 45        Jesse      James          89             73
# 17      Bridget    Johnson          92            100
# 46        Craig    Ferrell          94             96
# 22      Matthew     Walter          94             73
# 8        Robert     Martin          94             62
# 20        Linda      Clark          95             83
# 10      Jeffery       Mayo          97             78
# 26  Christopher      Rocha          97            100
# 18         Lisa    Stewart          98             83
# 42       Jeremy     Conner          98             85
# 0      Danielle       Wood         100             95

# %%
# Sort by science_score descending
df.sort_values(by="science_score", ascending=False)
# Out:
#      first_name  last_name  math_score  science_score
# 17      Bridget    Johnson          92            100
# 2        Joshua      Adams          61            100
# 34     Nicholas       Ross          73            100
# 26  Christopher      Rocha          97            100
# 3       Jeffrey     Zuniga          77             99
# 25      Matthew     Foster          88             98
# 46        Craig    Ferrell          94             96
# 5         Erica      Lynch          74             96
# 35       Andrea   Robinson          81             95
# 0      Danielle       Wood         100             95
# 28      Melanie      Baker          60             94
# 49      Michael   Valencia          65             91
# 16      Jeffrey      Perez          74             89
# 31      Jessica      Baker          81             89
# 42       Jeremy     Conner          98             85
# 14        Debra    Cameron          65             84
# 32       Amanda   Richards          77             84
# 4          Jill       Wong          75             83
# 18         Lisa    Stewart          98             83
# 20        Linda      Clark          95             83
# 21        Helen       Hahn          72             82
# 47       Joshua       Rice          67             80
# 41      Brandon     Burton          82             80
# 37    Christine      Hicks          65             80
# 1         Angel      Clark          67             78
# 10      Jeffery       Mayo          97             78
# 43        Keith  Henderson          76             77
# 23         Eric    Edwards          86             77
# 33       Teresa      Hurst          69             77
# 15          Amy    Parsons          73             77
# 29    Cassandra     Wright          70             75
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 12      Anthony    Hawkins          62             74
# 9       Anthony       Gray          65             74
# 45        Jesse      James          89             73
# 22      Matthew     Walter          94             73
# 48      Cynthia     Maddox          84             73
# 6      Patricia    Jackson          68             72
# 30      Lindsay    Hoffman          87             70
# 27        Colin      Ellis          77             70
# 19         Adam      Adams          61             70
# 13        James      Cohen          61             66
# 11      William     Bowman          87             65
# 7   Christopher     Daniel          66             64
# 44  Christopher      Brown          62             64
# 24        Susan       Rios          74             64
# 38     Michelle      Davis          84             63
# 40        Janet  Rodriguez          82             62
# 8        Robert     Martin          94             62

# %%
# Sort by multiple columns
df.sort_values(by=["science_score", "math_score"], ascending=[False, True])
# Out:
#      first_name  last_name  math_score  science_score
# 2        Joshua      Adams          61            100
# 34     Nicholas       Ross          73            100
# 17      Bridget    Johnson          92            100
# 26  Christopher      Rocha          97            100
# 3       Jeffrey     Zuniga          77             99
# 25      Matthew     Foster          88             98
# 5         Erica      Lynch          74             96
# 46        Craig    Ferrell          94             96
# 35       Andrea   Robinson          81             95
# 0      Danielle       Wood         100             95
# 28      Melanie      Baker          60             94
# 49      Michael   Valencia          65             91
# 16      Jeffrey      Perez          74             89
# 31      Jessica      Baker          81             89
# 42       Jeremy     Conner          98             85
# 14        Debra    Cameron          65             84
# 32       Amanda   Richards          77             84
# 4          Jill       Wong          75             83
# 20        Linda      Clark          95             83
# 18         Lisa    Stewart          98             83
# 21        Helen       Hahn          72             82
# 37    Christine      Hicks          65             80
# 47       Joshua       Rice          67             80
# 41      Brandon     Burton          82             80
# 1         Angel      Clark          67             78
# 10      Jeffery       Mayo          97             78
# 33       Teresa      Hurst          69             77
# 15          Amy    Parsons          73             77
# 43        Keith  Henderson          76             77
# 23         Eric    Edwards          86             77
# 29    Cassandra     Wright          70             75
# 12      Anthony    Hawkins          62             74
# 9       Anthony       Gray          65             74
# 36        Maria     Bright          66             74
# 39      Barbara   Williams          66             74
# 48      Cynthia     Maddox          84             73
# 45        Jesse      James          89             73
# 22      Matthew     Walter          94             73
# 6      Patricia    Jackson          68             72
# 19         Adam      Adams          61             70
# 27        Colin      Ellis          77             70
# 30      Lindsay    Hoffman          87             70
# 13        James      Cohen          61             66
# 11      William     Bowman          87             65
# 44  Christopher      Brown          62             64
# 7   Christopher     Daniel          66             64
# 24        Susan       Rios          74             64
# 38     Michelle      Davis          84             63
# 40        Janet  Rodriguez          82             62
# 8        Robert     Martin          94             62

# %% [markdown]
# ### 🧪 3. Filtering with Conditions

# %%
# Who scored at least 90 in math?
df[df["math_score"] >= 90]

# %%
# Who scored less than 70 in either subject?
df[(df["math_score"] < 70) | (df["science_score"] < 70)]

# %% [markdown]
# ### 🔗 4. Combining Filters

# %%
# Students with B+ or higher in both
df[(df["math_score"] >= 87) & (df["science_score"] >= 87)]

# %% [markdown]
# ### 🧾 5. Using `.query()` for Readability

# %%
# Same query using .query()
df.query("math_score >= 87 and science_score >= 87")

# %% [markdown]
# ### 🧪 Try It Yourself
#
# - Sort the dataset by first name alphabetically
# - Find students with the same math and science score
# - Use `.query()` to find students who scored over 95 in *either* subject

# %%
dat = {
    "name": ["joe", "kevin", "man", "kyle"],
    "hours": [22,23,55,43],
    "middle_in":["s", "d", "t", "g"],
    "science": [22,33,44,100],
    "math": [100,68,94,57]
}

m = pd.DataFrame(dat)

m.sort_values(by="name")

m.query("math >= 95 or science >= 95")
# Out:
#    name  hours middle_in  science  math
# 0   joe     22         s       22   100
# 3  kyle     43         g      100    57

# %% [markdown]
# ### 🧠 Mini-Challenge
#
# > Load `"data/survey.csv"` and:
# - Sort by the most recent signup date
# - Filter out anyone who didn't complete the survey (nulls or "N/A")
# - Use `.query()` to select rows with a specific condition of your choice

# %%
das = pd.read_csv("../../data/survey.csv")

myda = pd.DataFrame(das)

myda.sort_values(by="survey_date")

myda["survey_date"] = pd.to_datetime(myda["survey_date"], errors="coerce")

myda = myda[myda["survey_date"].notna()]
myda

myda.query("gpa != None")
# Out:
# /tmp/ipykernel_1798/1669816573.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   myda["survey_date"] = pd.to_datetime(myda["survey_date"], errors="coerce")
#     student_id  age             gender         major   gpa  \
# 6       S10006  NaN  Prefer not to say      Business   NaN
# 8       S10008  NaN               Male       History   4,0
# 9       S10009   18             Female           NaN  3.88
# 10      S10010  NaN         Non-binary            CS   NaN
# 11      S10011   18         Non-binary  Data Science   NaN
# ..         ...  ...                ...           ...   ...
# 114     S10114  NaN         Non-binary            CS   NaN
# 115     S10115   22             Female       History  3.75
# 116     S10116   18         Non-binary  Data Science   NaN
# 117     S10117  NaN                NaN       Biology   3.2
# 118     S10118   22         Non-binary       History   5.1
#
#     study_hours_per_week satisfaction_1_5 survey_date dorm_resident  \
# 6                    NaN                2  2025-09-07             N
# 8                    ten                3  2025-10-18           Yes
# 9                    NaN                2  2025-11-08             N
# 10                   ten                4  2025-09-09             Y
# 11                   NaN                4  2025-11-09            No
# ..                   ...              ...         ...           ...
# 114                  NaN              NaN  2025-11-08           Yes
# 115                  NaN              NaN  2025-11-01           Yes
# 116                 12.5              NaN  2025-09-28           Yes
# 117                    0              NaN  2025-10-31            No
# 118                  ten             five  2025-09-05           NaN
#
#     expected_grad_year       income_range commute_minutes clubs_member  \
# 6                 2028                NaN               0        FALSE
# 8                 2026             >$100k              -5         TRUE
# 9             twenty28             >$100k             NaN            1
# 10                2029             >$100k              28        FALSE
# 11            twenty28          $25k-$50k               0           No
# ..                 ...                ...             ...          ...
# 114                NaN  Prefer not to say             NaN            0
# 115                NaN          $50k-$75k               0            1
# 116                NaN             >$100k             NaN          Yes
# 117               2028              <$25k             NaN            1
# 118               2028              <$25k              -5          Yes
#
#     attendance_rate favorite_language             comments
# 6               NaN               SQL  Need more examples.
# 8               NaN                Go     Love the course.
# 9               NaN        JavaScript   Too much homework.
# 10              74%            Python                  NaN
# 11              NaN               C++     Love the course.
# ..              ...               ...                  ...
# 114            105%        JavaScript   Too much homework.
# 115             NaN                Go                  NaN
# 116             75%        JavaScript     Love the course.
# 117             NaN               NaN                  NaN
# 118             62%              Rust                  NaN
#
# [61 rows x 16 columns]

# %% [markdown]
# ### 📝 Summary
#
# | Task              | Code Example                                 |
# |-------------------|-----------------------------------------------|
# | Sort by column     | `df.sort_values(by="col")`                  |
# | Filter condition   | `df[df["col"] > value]`                     |
# | Combine filters    | `df[(cond1) & (cond2)]`                     |
# | Query method       | `df.query("col > value and col2 < value")`  |
