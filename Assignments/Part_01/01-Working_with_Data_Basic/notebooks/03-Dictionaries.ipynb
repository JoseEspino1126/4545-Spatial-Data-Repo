# %% [markdown]
# # 📘 03 - Python Dictionaries
#
# Dictionaries store key-value pairs for fast lookups.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and access dictionary items
# - Use dictionary methods like `.get()` and `.items()`

# %%
# 📚 Create a Dictionary
student = {'name': 'Alex', 'age': 21, 'major': 'CS'}
print(student)
# Out:
# {'name': 'Alex', 'age': 21, 'major': 'CS'}

# %%
# 🔍 Access Values
print(student['name'])
print(student.get('gpa', 'N/A'))
# Out:
# Alex
# N/A

# %%
# 🔁 Loop Over Dictionary
for key, value in student.items():
    print(key, '->', value)
# Out:
# name -> Alex
# age -> 21
# major -> CS

# %% [markdown]
# ## ✏️ Your Turn
# Create a dictionary to store information about your favorite book.

# %%
onepiece = {'name' : 'Luffy', 'fruit' : 'GumGumFruit', 'skills' : 'Eating'}
print(onepiece)
for key, value in onepiece.items():
    print(key , '->', value)
# Out:
# {'name': 'Luffy', 'fruit': 'GumGumFruit', 'skills': 'Eating'}
# name -> Luffy
# fruit -> GumGumFruit
# skills -> Eating
